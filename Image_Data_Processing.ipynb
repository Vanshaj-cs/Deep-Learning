# %% [markdown]
# <a href="https://colab.research.google.com/github/Vanshaj-cs/Deep-Learning/blob/main/Image_Data_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.   Reading a image and converting to numpy array
# 2.   Resizing an image
# 3.   converting rgb to grayscale

# %%
# !wget 'https://imgs.search.brave.com/_SggsIJjJO5MGkIPC9nabmLW2bO_4UztZMDEm_E0BW4/rs:fit:860:0:0:0/g:ce/aHR0cHM6Ly9tZWRp/YS5nZXR0eWltYWdl/cy5jb20vaWQvNTIz/MjcxNTM4L3Bob3Rv/L3JvdHR3ZWlsZXIt/bWl4LXB1cHB5Lmpw/Zz9zPTYxMng2MTIm/dz0wJms9MjAmYz1z/Y2s2WDNfTVd3eXVl/TURlb3IyOWRsTmp5/U3RQRV9VNllVRXRB/T2JVaWdVPQ'
# Out:
# --2025-08-24 12:23:56--  https://imgs.search.brave.com/_SggsIJjJO5MGkIPC9nabmLW2bO_4UztZMDEm_E0BW4/rs:fit:860:0:0:0/g:ce/aHR0cHM6Ly9tZWRp/YS5nZXR0eWltYWdl/cy5jb20vaWQvNTIz/MjcxNTM4L3Bob3Rv/L3JvdHR3ZWlsZXIt/bWl4LXB1cHB5Lmpw/Zz9zPTYxMng2MTIm/dz0wJms9MjAmYz1z/Y2s2WDNfTVd3eXVl/TURlb3IyOWRsTmp5/U3RQRV9VNllVRXRB/T2JVaWdVPQ
# Resolving imgs.search.brave.com (imgs.search.brave.com)... 3.169.36.113, 3.169.36.99, 3.169.36.73, ...
# Connecting to imgs.search.brave.com (imgs.search.brave.com)|3.169.36.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25603 (25K) [image/jpeg]
# Saving to: ‘T2JVaWdVPQ’
#
# T2JVaWdVPQ          100%[===================>]  25.00K  --.-KB/s    in 0s
#
# 2025-08-24 12:23:56 (169 MB/s) - ‘T2JVaWdVPQ’ saved [25603/25603]

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img = mpimg.imread('dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (407, 612, 3)

# %%
print(img)
# Out:
# [[[177 186 183]
#   [177 186 183]
#   [177 186 183]
#   ...
#   [155 146 129]
#   [155 146 129]
#   [155 146 129]]
#
#  [[177 186 183]
#   [177 186 183]
#   [177 186 183]
#   ...
#   [153 144 127]
#   [153 144 127]
#   [153 144 127]]
#
#  [[177 186 183]
#   [177 186 183]
#   [177 186 183]
#   ...
#   [151 142 125]
#   [151 142 125]
#   [151 142 125]]
#
#  ...
#
#  [[212 214 211]
#   [212 214 211]
#   [212 214 211]
#   ...
#   [221 222 217]
#   [221 222 217]
#   [221 222 217]]
#
#  [[211 213 210]
#   [211 213 210]
#   [211 213 210]
#   ...
#   [221 222 217]
#   [221 222 217]
#   [221 222 217]]
#
#  [[211 213 210]
#   [211 213 210]
#   [211 213 210]
#   ...
#   [221 222 217]
#   [221 222 217]
#   [221 222 217]]]

# %%
img_plot = plt.imshow(img)
plt.show()

# %%
from PIL import Image

# %%
img = Image.open('/content/dog.jpg')
img_resized = img.resize((200,200))

# %%
img_resized.save('dog_image_resized.jpg')

# %%
img_res = mpimg.imread('dog_image_resized.jpg')
img_plot = plt.imshow(img_res)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import cv2

# %%
img = cv2.imread('/content/dog.jpg')

# %%
img.shape
# Out:
# (407, 612, 3)

# %%
grayscale_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=612x407>

# %%
cv2.imwrite('dog_grayscale_image.jpg', grayscale_image)
# Out:
# True
